# %% [markdown]
# ## Gaussian Naive Bayes with `sklearn`

# %%
import numpy as np
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %%
# Generate a mixture of two Gaussians.
X0 = np.random.multivariate_normal([-1, 0], 0.5*np.identity(2), size=100)
X1 = np.random.multivariate_normal([1, 0], 0.5*np.identity(2), size=100)
X = np.concatenate([X0, X1])

# Assign class labels
y0 = np.zeros(len(X0))
y1 = np.ones(len(X1))
y = np.concatenate([y0, y1])

# Split dataset into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# Plot clouds
plt.plot(X0[:,0], X0[:,1], 'ro')
plt.plot(X1[:,0], X1[:,1], 'bo')

# %%
# Fit GNB model on training data, predict on test data.
GNB = GaussianNB()
GNB.fit(X_train, y_train)
y_ = GNB.predict(X_test)
mis_rate = sum(y_ != y_test)/len(y_)
print(f"misclassification rate: {mis_rate}")

# Identify misclassifications.
i_bad = (y_ != y_test)
X_bad = X_test[i_bad, :]

# Plot clouds with misclassifications emphasized.
plt.plot(X0[:,0], X0[:,1], 'ro')
plt.plot(X1[:,0], X1[:,1], 'bo')
plt.plot(X_bad[:,0], X_bad[:,1], 'o', color="mediumspringgreen", markersize=12, markeredgecolor='k')
plt.show()
# Out:
# misclassification rate: 0.06
