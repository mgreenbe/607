# %% [markdown]
# ## Activity: Decision trees and random forests

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
import pandas
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# Browse the data in `spambase.csv`.

# %%
data = read_csv("spambase.csv")
values = data.values # Turn a pandas dataframe into a numpy matrix
X = values[:, :57] # features
y = values[:, 57] # target

# %% [markdown]
# Separate the data into training and test sets.
# Train a **decision tree classifier** (`DecisionTreeClassifier`) on the training test.
# Compute the accuracy on the test set.
# Plot feature importances.

# %%
X_tr, X_te, y_tr, y_te = train_test_split(X, y, test_size=0.2)
C = DecisionTreeClassifier()
C.fit(X_tr, y_tr)
y_p = C.predict(X_te)
print(sum(y_p == y_te)/len(y_p))
# Out:
# 0.9066232356134636

# %% [markdown]
# Train a **bagging classifier** (`BaggingClassifier`) on the training test.
# Compute the accuracy on the test set.
# Plot feature importances.

# %%
C = BaggingClassifier(n_estimators=100, oob_score=True)
C.fit(X_tr, y_tr)
print(f"OOB score: {C.oob_score_}")
y_p = C.predict(X_te)
print(sum(y_p == y_te)/len(y_p))
# Out:
# OOB score: 0.9445652173913044
# 0.9489685124864278

# %% [markdown]
# Train a **random forest classifier** (`RandomForestClassifier`) on the training test.
# Compute the accuracy on the test set.
# Plot feature importances.

# %%
C = RandomForestClassifier(n_estimators=100, oob_score=True)
C.fit(X_tr, y_tr)
print(f"OOB score: {C.oob_score_}")
y_p = C.predict(X_te)
print(sum(y_p == y_te)/len(y_p))
plt.figure(figsize=(18, 12))
plt.barh(np.array(list(data))[I], C.feature_importances_[I])
plt.show()
# Out:
# OOB score: 0.9538043478260869
# 0.9500542888165038
