# %% [markdown]
# ## $K$-nearest neighbors classification with `sklearn`

# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split, cross_val_score
from matplotlib import pyplot as plt

# %%
# Generate a mixture of two Gaussians.
X0 = np.random.multivariate_normal([0.5, 0.5*np.sqrt(3)], 0.3*np.identity(2), size=100)
X1 = np.random.multivariate_normal([-0.5, 0.5*np.sqrt(3)], 0.3*np.identity(2), size=100)
X2 = np.random.multivariate_normal([0, -1], 0.3*np.identity(2), size=100)
X = np.concatenate([X0, X1, X2])

# Assign class labels
y0 = np.zeros(len(X0))
y1 = np.ones(len(X1))
y2 = 2*np.ones(len(X2))
y = np.concatenate([y0, y1, y2])

# Split dataset into training and testing data
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.25)

print(X_train.shape, X_test.shape)

# cv_scores = []
# for k in range(1, 100):
#     C = KNeighborsClassifier(n_neighbors=k)
#     C.fit(X_train, Y_train)
#     y_ = C.predict(X_test)
#     cv_score = cross_val_score(C, X_train, Y_train, scoring="accuracy", cv=5)
#     cv_scores.append(cv_score)

C = KNeighborsClassifier(n_neighbors=14)
C.fit(X_train, Y_train)
y_ = C.predict(X_test)
sum(y_ == Y_test)/len(y_)
print(f"Misclassification rate: {1 - sum(y_ == Y_test)/len(y_):.2f}")




bad_indices = (y_ != Y_test)
X_test[bad_indices]

# Plot clouds
plt.figure(figsize=(6, 6))
plt.xlim(-2, 2)
plt.ylim(-2, 2)
plt.plot(X0[:,0], X0[:,1], 'ro')
plt.plot(X1[:,0], X1[:,1], 'bo')
plt.plot(X2[:,0], X2[:,1], 'mo')
plt.plot(X_test[bad_indices][:,0], X_test[bad_indices][:,1], 'o', color="lightcoral", markersize=12, markeredgecolor='k')
# Out:
# (225, 2) (75, 2)
# Misclassification rate: 0.19

# %%
cv_scores = np.array(cv_scores)
cv_scores.shape
plt.plot(np.mean(cv_scores, axis=1))
print(np.argmax(np.mean(cv_scores, axis=1)), range(1, 100)[np.argmax(np.mean(cv_scores, axis=1))])
# Out:
# 13 14

# %%
from sklearn.linear_model import LogisticRegression

C = LogisticRegression()
C.fit(X_train, Y_train)
y_ = C.predict(X_test)
print(f"Misclassification rate: {1 - sum(y_ == Y_test)/len(y_):.2f}")

bad_indices = (y_ != Y_test)
X_test[bad_indices]

# Plot clouds
plt.figure(figsize=(6, 6))
plt.xlim(-2, 2)
plt.ylim(-2, 2)
plt.plot(X0[:,0], X0[:,1], 'ro')
plt.plot(X1[:,0], X1[:,1], 'bo')
plt.plot(X2[:,0], X2[:,1], 'mo')
plt.plot(X_test[bad_indices][:,0], X_test[bad_indices][:,1], 'o', color="lightcoral", markersize=12, markeredgecolor='k')
# Out:
# Misclassification rate: 0.13

# %%
from sklearn.naive_bayes import GaussianNB

C = GaussianNB()
C.fit(X_train, Y_train)
y_ = C.predict(X_test)
print(f"Misclassification rate: {1 - sum(y_ == Y_test)/len(y_):.2f}")

bad_indices = (y_ != Y_test)
X_test[bad_indices]

# Plot clouds
plt.figure(figsize=(6, 6))
plt.xlim(-2, 2)
plt.ylim(-2, 2)
plt.plot(X0[:,0], X0[:,1], 'ro')
plt.plot(X1[:,0], X1[:,1], 'bo')
plt.plot(X2[:,0], X2[:,1], 'mo')
plt.plot(X_test[bad_indices][:,0], X_test[bad_indices][:,1], 'o', color="lightcoral", markersize=12, markeredgecolor='k')
# Out:
# Misclassification rate: 0.21

# %%
cross_val_score?
